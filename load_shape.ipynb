# %%
import os, sys
import pandas as pd
import numpy as np
import numpy.matlib
import scipy as sp

import geopandas as gpd

# Plotting
import matplotlib.pyplot as plt
import seaborn as sns

# %%
shape_file = gpd.read_file('/Users/lindenmp/Dropbox/PersonalProjects/NASA_aus_firedata/data/DL_FIRE_V1_101558/fire_nrt_V1_101558.shp')
# shape_file = gpd.read_file('/Users/lindenmp/Dropbox/PersonalProjects/NASA_aus_firedata/data/DL_FIRE_V1_101558/fire_archive_V1_101558.shp')

# %%
shape_file.set_index('ACQ_DATE', inplace = True)

# %%
shape_file.tail()
# Out:
#             LATITUDE  LONGITUDE  BRIGHT_TI4  SCAN  TRACK ACQ_TIME SATELLITE  \
# ACQ_DATE
# 2020-01-29 -32.41764  122.97107       310.9  0.36   0.57     1730         N
# 2020-01-29 -32.41904  122.99052       310.8  0.36   0.57     1730         N
# 2020-01-29 -32.42443  122.99001       308.9  0.36   0.57     1730         N
# 2020-01-29 -32.42954  122.98567       308.8  0.36   0.57     1730         N
# 2020-01-29 -32.42982  122.98959       302.3  0.36   0.57     1730         N
#
#            INSTRUMENT CONFIDENCE VERSION  BRIGHT_TI5  FRP DAYNIGHT  \
# ACQ_DATE
# 2020-01-29      VIIRS          n  1.0NRT       289.7  1.2        N
# 2020-01-29      VIIRS          n  1.0NRT       289.6  1.2        N
# 2020-01-29      VIIRS          n  1.0NRT       289.8  1.3        N
# 2020-01-29      VIIRS          n  1.0NRT       290.0  1.1        N
# 2020-01-29      VIIRS          n  1.0NRT       289.3  1.3        N
#
#                                geometry
# ACQ_DATE
# 2020-01-29  POINT (122.97107 -32.41764)
# 2020-01-29  POINT (122.99052 -32.41904)
# 2020-01-29  POINT (122.99001 -32.42443)
# 2020-01-29  POINT (122.98567 -32.42954)
# 2020-01-29  POINT (122.98959 -32.42982)

# %% [markdown]
# Plot a couple of dates

# %%
fig, ax = plt.subplots(figsize = (15,15))
shape_file.loc['2019-10-01'].plot(ax = ax)
shape_file.loc['2020-01-29'].plot(ax = ax)

# %% [markdown]
# Plot same date, but color day/night differently

# %%
fig, ax = plt.subplots(figsize = (15,15))
shape_file[shape_file['DAYNIGHT'] == 'D'].loc['2020-01-29'].plot(ax = ax, color = 'blue')
shape_file[shape_file['DAYNIGHT'] == 'N'].loc['2020-01-29'].plot(ax = ax, color = 'red')
